# %% [markdown]
# # AA Projekt

# %% [markdown]
# ## Data Collection and Preparation

# %%
import numpy as np
import pandas as pd

# %%
charging_data = pd.read_csv("charging_sessions.csv", index_col="id")

# %%
charging_data.head()
# Out:
#                           Unnamed: 0             connectionTime  \
# id
# 5e23b149f9af8b5fe4b973cf           0  2020-01-02 13:08:54+00:00
# 5e23b149f9af8b5fe4b973d0           1  2020-01-02 13:36:50+00:00
# 5e23b149f9af8b5fe4b973d1           2  2020-01-02 13:56:35+00:00
# 5e23b149f9af8b5fe4b973d2           3  2020-01-02 13:59:58+00:00
# 5e23b149f9af8b5fe4b973d3           4  2020-01-02 14:00:01+00:00
#
#                                      disconnectTime  \
# id
# 5e23b149f9af8b5fe4b973cf  2020-01-02 19:11:15+00:00
# 5e23b149f9af8b5fe4b973d0  2020-01-02 22:38:21+00:00
# 5e23b149f9af8b5fe4b973d1  2020-01-03 00:39:22+00:00
# 5e23b149f9af8b5fe4b973d2  2020-01-02 16:38:39+00:00
# 5e23b149f9af8b5fe4b973d3  2020-01-02 22:08:40+00:00
#
#                                    doneChargingTime  kWhDelivered  \
# id
# 5e23b149f9af8b5fe4b973cf  2020-01-02 17:31:35+00:00        25.016
# 5e23b149f9af8b5fe4b973d0  2020-01-02 20:18:05+00:00        33.097
# ...

# %%
charging_data.describe(include="all")
# Out:
#           Unnamed: 0             connectionTime             disconnectTime  \
# count   66450.000000                      66450                      66450
# unique           NaN                      64839                      64906
# top              NaN  2019-07-08 14:46:17+00:00  2021-07-22 14:35:55+00:00
# freq             NaN                         14                          7
# mean     4726.102062                        NaN                        NaN
# std      3568.025394                        NaN                        NaN
# min         0.000000                        NaN                        NaN
# 25%      1845.000000                        NaN                        NaN
# 50%      3960.000000                        NaN                        NaN
# 75%      7027.000000                        NaN                        NaN
# max     15291.000000                        NaN                        NaN
#
#                  doneChargingTime  kWhDelivered  \
# ...

# %%
charging_data.columns
# Out:
# Index(['Unnamed: 0', 'connectionTime', 'disconnectTime', 'doneChargingTime',
#        'kWhDelivered', 'sessionID', 'siteID', 'spaceID', 'stationID',
#        'timezone', 'userID', 'userInputs'],
#       dtype='object')

# %%
charging_data.notnull()
# Out:
#                           Unnamed: 0  connectionTime  disconnectTime  \
# id
# 5e23b149f9af8b5fe4b973cf        True            True            True
# 5e23b149f9af8b5fe4b973d0        True            True            True
# 5e23b149f9af8b5fe4b973d1        True            True            True
# 5e23b149f9af8b5fe4b973d2        True            True            True
# 5e23b149f9af8b5fe4b973d3        True            True            True
# ...                              ...             ...             ...
# 5d574ad2f9af8b4c10c03652        True            True            True
# 5d574ad2f9af8b4c10c03653        True            True            True
# 5d574ad2f9af8b4c10c03654        True            True            True
# 5d574ad2f9af8b4c10c03655        True            True            True
# 5d574ad2f9af8b4c10c03656        True            True            True
#
#                           doneChargingTime  kWhDelivered  sessionID  siteID  \
# id
# ...

# %%
charging_data.drop_duplicates(subset=["sessionID"])
# Out:
#                           Unnamed: 0             connectionTime  \
# id
# 5e23b149f9af8b5fe4b973cf           0  2020-01-02 13:08:54+00:00
# 5e23b149f9af8b5fe4b973d0           1  2020-01-02 13:36:50+00:00
# 5e23b149f9af8b5fe4b973d1           2  2020-01-02 13:56:35+00:00
# 5e23b149f9af8b5fe4b973d2           3  2020-01-02 13:59:58+00:00
# 5e23b149f9af8b5fe4b973d3           4  2020-01-02 14:00:01+00:00
# ...                              ...                        ...
# 5d2fbdd3f9af8b4d0dd0d54a        8670  2019-07-01 21:49:12+00:00
# 5d2fbdd3f9af8b4d0dd0d54b        8671  2019-07-01 21:58:45+00:00
# 5d2fbdd3f9af8b4d0dd0d54c        8672  2019-07-01 22:02:21+00:00
# 5d2fbdd3f9af8b4d0dd0d54d        8673  2019-07-01 22:23:44+00:00
# 5d2fbdd3f9af8b4d0dd0d54e        8674  2019-07-01 22:36:08+00:00
#
#                                      disconnectTime  \
# id
# 5e23b149f9af8b5fe4b973cf  2020-01-02 19:11:15+00:00
# 5e23b149f9af8b5fe4b973d0  2020-01-02 22:38:21+00:00
# ...

# %% [markdown]
# ## Descriptive Analytics

# %% [markdown]
# ### Temporal Patterns and Seasonality

# %% [markdown]
# ### Key Performance Indicators

# %% [markdown]
# ### Site Characteristics

# %% [markdown]
# ### Site Characteristics

# %% [markdown]
# ## Cluster Analysis

# %% [markdown]
# ## Utilization Prediction

# %% [markdown]
# ### Predictive Model 1

# %% [markdown]
# ### Predictive Model 2

# %% [markdown]
# ### Business Case
