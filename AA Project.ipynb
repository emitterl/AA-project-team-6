# %% [markdown]
# # AA Projekt

# %% [markdown]
# ## Data Collection and Preparation

# %%
import numpy as np
import pandas as pd

# %%
charging_data = pd.read_csv("charging_sessions.csv", index_col="Unnamed: 0")

# %%
charging_data.head()
# Out:
#                          id             connectionTime  \
# 0  5e23b149f9af8b5fe4b973cf  2020-01-02 13:08:54+00:00
# 1  5e23b149f9af8b5fe4b973d0  2020-01-02 13:36:50+00:00
# 2  5e23b149f9af8b5fe4b973d1  2020-01-02 13:56:35+00:00
# 3  5e23b149f9af8b5fe4b973d2  2020-01-02 13:59:58+00:00
# 4  5e23b149f9af8b5fe4b973d3  2020-01-02 14:00:01+00:00
#
#               disconnectTime           doneChargingTime  kWhDelivered  \
# 0  2020-01-02 19:11:15+00:00  2020-01-02 17:31:35+00:00        25.016
# 1  2020-01-02 22:38:21+00:00  2020-01-02 20:18:05+00:00        33.097
# 2  2020-01-03 00:39:22+00:00  2020-01-02 16:35:06+00:00         6.521
# 3  2020-01-02 16:38:39+00:00  2020-01-02 15:18:45+00:00         2.355
# 4  2020-01-02 22:08:40+00:00  2020-01-02 18:17:30+00:00        13.375
#
#                                 sessionID  siteID  spaceID    stationID  \
# 0  1_1_179_810_2020-01-02 13:08:53.870034       1  AG-3F30  1-1-179-810
# 1  1_1_193_825_2020-01-02 13:36:49.599853       1  AG-1F01  1-1-193-825
# 2  1_1_193_829_2020-01-02 13:56:35.214993       1  AG-1F03  1-1-193-829
# 3  1_1_193_820_2020-01-02 13:59:58.309319       1  AG-1F04  1-1-193-820
# 4  1_1_193_819_2020-01-02 14:00:00.779967       1  AG-1F06  1-1-193-819
#
#               timezone  userID  \
# 0  America/Los_Angeles   194.0
# 1  America/Los_Angeles  4275.0
# 2  America/Los_Angeles   344.0
# 3  America/Los_Angeles  1117.0
# 4  America/Los_Angeles   334.0
#
#                                           userInputs
# 0  [{'WhPerMile': 250, 'kWhRequested': 25.0, 'mil...
# 1  [{'WhPerMile': 280, 'kWhRequested': 70.0, 'mil...
# 2  [{'WhPerMile': 400, 'kWhRequested': 8.0, 'mile...
# 3  [{'WhPerMile': 400, 'kWhRequested': 8.0, 'mile...
# 4  [{'WhPerMile': 400, 'kWhRequested': 16.0, 'mil...

# %%
charging_data.tail()
# Out:
#                              id             connectionTime  \
# 10083  5d574ad2f9af8b4c10c03652  2019-07-31 18:08:04+00:00
# 10084  5d574ad2f9af8b4c10c03653  2019-07-31 18:40:41+00:00
# 10085  5d574ad2f9af8b4c10c03654  2019-07-31 19:04:40+00:00
# 10086  5d574ad2f9af8b4c10c03655  2019-07-31 19:19:47+00:00
# 10087  5d574ad2f9af8b4c10c03656  2019-07-31 19:21:47+00:00
#
#                   disconnectTime           doneChargingTime  kWhDelivered  \
# 10083  2019-07-31 23:29:18+00:00  2019-07-31 23:30:18+00:00        28.787
# 10084  2019-08-01 00:59:42+00:00  2019-07-31 21:44:23+00:00         7.787
# 10085  2019-07-31 22:44:22+00:00  2019-07-31 22:45:21+00:00        11.274
# 10086  2019-08-01 00:34:51+00:00  2019-07-31 21:25:30+00:00        11.589
# 10087  2019-07-31 22:00:04+00:00  2019-07-31 20:51:34+00:00         0.897
#
#                                     sessionID  siteID  spaceID    stationID  \
# 10083  1_1_179_809_2019-07-31 18:08:04.432654       1  AG-3F27  1-1-179-809
# 10084  1_1_179_810_2019-07-31 18:40:40.900203       1  AG-3F30  1-1-179-810
# 10085  1_1_191_795_2019-07-31 19:04:40.098273       1  AG-4F51  1-1-191-795
# 10086  1_1_191_778_2019-07-31 19:19:46.919358       1  AG-4F43  1-1-191-778
# 10087  1_1_178_817_2019-07-31 19:21:46.727697       1  AG-1F09  1-1-178-817
#
#                   timezone  userID  \
# 10083  America/Los_Angeles   393.0
# 10084  America/Los_Angeles   220.0
# 10085  America/Los_Angeles  1974.0
# 10086  America/Los_Angeles   942.0
# 10087  America/Los_Angeles     NaN
#
#                                               userInputs
# 10083  [{'WhPerMile': 240, 'kWhRequested': 31.2, 'mil...
# 10084  [{'WhPerMile': 333, 'kWhRequested': 6.66, 'mil...
# 10085  [{'WhPerMile': 333, 'kWhRequested': 19.98, 'mi...
# 10086  [{'WhPerMile': 275, 'kWhRequested': 22.0, 'mil...
# 10087                                                NaN

# %%
charging_data.columns
# Out:
# Index(['id', 'connectionTime', 'disconnectTime', 'doneChargingTime',
#        'kWhDelivered', 'sessionID', 'siteID', 'spaceID', 'stationID',
#        'timezone', 'userID', 'userInputs'],
#       dtype='object')

# %%
charging_data.notnull()
# Out:
#          id  connectionTime  disconnectTime  doneChargingTime  kWhDelivered  \
# 0      True            True            True              True          True
# 1      True            True            True              True          True
# 2      True            True            True              True          True
# 3      True            True            True              True          True
# 4      True            True            True              True          True
# ...     ...             ...             ...               ...           ...
# 10083  True            True            True              True          True
# 10084  True            True            True              True          True
# 10085  True            True            True              True          True
# 10086  True            True            True              True          True
# 10087  True            True            True              True          True
#
#        sessionID  siteID  spaceID  stationID  timezone  userID  userInputs
# 0           True    True     True       True      True    True        True
# 1           True    True     True       True      True    True        True
# 2           True    True     True       True      True    True        True
# 3           True    True     True       True      True    True        True
# 4           True    True     True       True      True    True        True
# ...          ...     ...      ...        ...       ...     ...         ...
# 10083       True    True     True       True      True    True        True
# 10084       True    True     True       True      True    True        True
# 10085       True    True     True       True      True    True        True
# 10086       True    True     True       True      True    True        True
# 10087       True    True     True       True      True   False       False
#
# [66450 rows x 12 columns]

# %% [markdown]
# ## Descriptive Analytics

# %% [markdown]
# ### Temporal Patterns and Seasonality

# %% [markdown]
# ### Key Performance Indicators

# %% [markdown]
# ### Site Characteristics

# %% [markdown]
# ### Site Characteristics

# %% [markdown]
# ## Cluster Analysis

# %% [markdown]
# ## Utilization Prediction

# %% [markdown]
# ### Predictive Model 1

# %% [markdown]
# ### Predictive Model 2

# %% [markdown]
# ### Business Case
